# %%
import pandas as pd

# %%
# data ingestion
df=pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
### no missing values present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    193573 non-null  float64
#  1   cut      193573 non-null  object
#  2   color    193573 non-null  object
#  3   clarity  193573 non-null  object
#  4   depth    193573 non-null  float64
#  5   table    193573 non-null  float64
#  6   x        193573 non-null  float64
#  7   y        193573 non-null  float64
#  8   z        193573 non-null  float64
#  9   price    193573 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 14.8+ MB

# %%
df.drop(labels='id',axis=1)
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
df.head()   # id column is dropped
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## check for duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
## segregate the data into numerical and categorical columns
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print(numerical_columns)
print(categorical_columns)  # categorical columns are 'cut','color','clarity'
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df[numerical_columns].describe()
# Out:
#                carat          depth          table              x  \
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        0.790688      61.820574      57.227675       5.715312
# std         0.462688       1.081704       1.918844       1.109422
# min         0.200000      52.100000      49.000000       0.000000
# 25%         0.400000      61.300000      56.000000       4.700000
# 50%         0.700000      61.900000      57.000000       5.700000
# 75%         1.030000      62.400000      58.000000       6.510000
# max         3.500000      71.600000      79.000000       9.650000
#
#                    y              z          price
# count  193573.000000  193573.000000  193573.000000
# mean        5.720094       3.534246    3969.155414
# std         1.102333       0.688922    4034.374138
# min         0.000000       0.000000     326.000000
# 25%         4.710000       2.900000     951.000000
# 50%         5.720000       3.530000    2401.000000
# ...

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    #sns.displot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    #sns.displot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
##correlation
sns.heatmap(df[numerical_columns].corr(), annot=True)
plt.show()

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.drop(labels='id',axis=1,inplace=True)

# %%
#df.drop(labels=['x','y','z'],axis=1,inplace=True)    # dropping the id column

# %%
sns.pairplot(df)

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8}

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}

# %%
df.replace({'cut':cut_map,'clarity':clarity_map,'color':color_map},inplace=True)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.pairplot(df)
#
# File c:\Users\NEW NEW\housepricingk\venv\lib\site-packages\seaborn\axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File c:\Users\NEW NEW\housepricingk\venv\lib\site-packages\seaborn\axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
#    1415
#    1416 Parameters
#    (...)
#    1422
#    1423 """
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer  ##handling missing values
from sklearn.preprocessing import StandardScaler ## Handling feature scaling
